# %%
import pandas as pd
import matplotlib

# %%
surveys_df = pd.read_csv('surveys.csv')
surveys_df.head()
surveys_df.columns
pd.unique(surveys_df['species_id'])

#Two data
surveys_df2 = pd.read_csv('surveys.csv')
surveys_df2.head()
surveys_df2.columns
pd.unique(surveys_df2['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
surveys_df['weight'].describe()
surveys_df['weight'].max()
surveys_df['weight'].min()
surveys_df['weight'].mean()
surveys_df['weight'].std()
surveys_df['weight'].count()
 
surveys_df2['weight'].describe()
surveys_df2['weight'].max()
surveys_df2['weight'].min()
surveys_df2['weight'].mean()
surveys_df2['weight'].std()
surveys_df2['weight'].count()
# Out:
# 32283

# %%
grouped_data = surveys_df.groupby('sex')
grouped_data.mean(numeric_only=True)

grouped_data2 = surveys_df.groupby('species_id')
grouped_data.mean(numeric_only=True)

grouped_data.describe()
# Out:
#     record_id                                                               \
#         count          mean           std  min      25%      50%       75%
# sex
# F     15690.0  18036.412046  10423.089000  3.0  8917.50  18075.5  27250.00
# M     17348.0  17754.835601  10132.203323  1.0  8969.75  17727.5  26454.25
#
#                 month            ... hindfoot_length         weight  \
#          max    count      mean  ...             75%   max    count
# sex                              ...
# F    35547.0  15690.0  6.583047  ...            36.0  64.0  15303.0
# M    35548.0  17348.0  6.392668  ...            36.0  58.0  16879.0
#
#
#           mean        std  min   25%   50%   75%    max
# sex
# F    42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    42.995379  36.184981  4.0  20.0  39.0  49.0  280.0
#
# [2 rows x 56 columns]

# %%
grouped_data2.describe()
# Out:
#            record_id                                                          \
#                count          mean           std      min       25%      50%
# species_id
# AB             303.0  13201.702970   5835.874869   3126.0   7604.00  13829.0
# AH             437.0  21631.716247   7194.381201   1446.0  15507.00  21600.0
# AS               2.0  19760.000000   1170.968830  18932.0  19346.00  19760.0
# BA              46.0  18586.043478    921.349203  16598.0  17972.50  18803.0
# CB              50.0  18300.460000   7271.702586   3189.0  13227.00  19590.5
# CM              13.0   4055.000000   2789.266660   3190.0   3263.00   3291.0
# CQ              16.0   5718.062500   1899.301607   3200.0   3720.75   6199.0
# CS               1.0  15878.000000           NaN  15878.0  15878.00  15878.0
# CT               1.0  28988.000000           NaN  28988.0  28988.00  28988.0
# CU               1.0  21209.000000           NaN  21209.0  21209.00  21209.0
# ...

# %%
species_counts = surveys_df.groupby('species_id')['record_id'].count()
surveys_df['weight']*2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 35544      NaN
# 35545      NaN
# 35546     28.0
# 35547    102.0
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %%
# %matplotlib inline
species_counts.plot(kind='bar');

d= {'one': pd.Series([1.,2.,3.], index=['a','b','c']),'two': pd.Series([1.,2.,3.,4.], index=['a','b','c','d'])}
pd.DataFrame(d)

my_df=pd.DataFrame(d)
my_df.plot(kind='bar', stacked=True, title='Results')
# Out:
# <Axes: title={'center': 'Test'}>
